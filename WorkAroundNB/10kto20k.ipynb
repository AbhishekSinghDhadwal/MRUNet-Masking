# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, BatchNormalization, Activation, add
from keras.models import Model, model_from_json
from keras.optimizers import Adam
from keras.layers.advanced_activations import ELU, LeakyReLU
from keras.utils.vis_utils import plot_model
from keras import backend as K 
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
os.chdir("/content/drive/My Drive/CelebAMaskHQ/")
# !ls
#img_files = next(os.walk('images/'))[2]
#leye_files = next(os.walk('l_eye/'))[2]
#reye_files = next(os.walk('r_eye/'))[2]
#llip_files = next(os.walk('l_lip/'))[2]
#ulip_files = next(os.walk('u_lip/'))[2]

# Used to display the differences between the number of masks available
# For each folder
#print(len(img_files))
#print(len(leye_files))
#print(len(reye_files))
#print(len(llip_files))
#print(len(ulip_files))

# Checks number of valid images
# CHANGE I FOR EACH ITERATION TYPE
i = 10000
count = 0
# Stores image and mask arrays
X2 = []
Y2 = []
pbar = tqdm(total = 10000)
while(i < 20000):    
    img_f1 = "/content/drive/My Drive/CelebAMaskHQ/images/"+str(i)+".jpg"
    if(os.path.exists(img_f1)):
        print("Image "+img_f1+" exists")
        if(os.path.exists('/content/drive/My Drive/CelebAMaskHQ/l_eye/'+str(i)+'_l_eye.png') and os.path.exists('/content/drive/My Drive/CelebAMaskHQ/r_eye/'+str(i)+'_r_eye.png') and os.path.exists('/content/drive/My Drive/CelebAMaskHQ/l_lip/'+str(i)+'_l_lip.png') and os.path.exists('/content/drive/My Drive/CelebAMaskHQ/u_lip/'+str(i)+'_u_lip.png') ):                
            
            # NOTE : The above if case is made in order to compensate for incomplete data
            # i.e there is a lack of masks for certain images, as noted by the 
            # difference of number of file objects per mask in the dataset

            # Taking main image as input and resizing
            img = cv2.imread('images/'+str(i)+'.jpg', cv2.IMREAD_COLOR)
            resized_img = cv2.resize(img,(256, 192), interpolation = cv2.INTER_CUBIC)
        
            X2.append(resized_img)
            # We are reading each and every mask available
            # In accordance to the dataset provided
            leye = cv2.imread('l_eye/{}'.format(str(i)+'_l_eye.png'), cv2.IMREAD_GRAYSCALE)
            reye = cv2.imread('r_eye/{}'.format(str(i)+'_r_eye.png'), cv2.IMREAD_GRAYSCALE)
            llip = cv2.imread('l_lip/{}'.format(str(i)+'_l_lip.png'), cv2.IMREAD_GRAYSCALE)
            ulip = cv2.imread('u_lip/{}'.format(str(i)+'_u_lip.png'), cv2.IMREAD_GRAYSCALE)

            # We resize our data to fit params of MultiResUNet
            resized_leye = cv2.resize(leye,(256, 192), interpolation = cv2.INTER_CUBIC)
            resized_reye = cv2.resize(reye,(256, 192), interpolation = cv2.INTER_CUBIC)
            resized_llip = cv2.resize(llip,(256, 192), interpolation = cv2.INTER_CUBIC)
            resized_ulip = cv2.resize(ulip,(256, 192), interpolation = cv2.INTER_CUBIC)

            # The below statements combine all the four masks into one picture
            # In order to satisfy question requirements(preprocessing)
            op = np.maximum(np.array(resized_leye),np.array(resized_reye))
            op = np.maximum(op, np.array(resized_llip))
            op = np.maximum(op,np.array(resized_ulip))

            count += 1
            Y2.append(op)
            pbar.update(1)
            print("Picture "+str(i)+" is valid")

        i += 1
        print("Iteration "+str(i)+" complete")

np.save('X2',X2)
np.save('Y2',Y2)
print("The number of valid images(images entered) : "+str(count))        
pbar.close()
# Out:
# Mounted at /content/drive
# images	l_eye  l_lip  r_eye  u_lip
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 1/10000 [00:00<18:26,  9.03it/s]
# Image /content/drive/My Drive/CelebAMaskHQ/images/10000.jpg exists
# Picture 10000 is valid
# Iteration 10001 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10001.jpg exists
# Picture 10001 is valid
# Iteration 10002 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10002.jpg exists
#   0%|          | 3/10000 [00:00<17:01,  9.79it/s]
#   0%|          | 5/10000 [00:00<15:54, 10.47it/s]
# Picture 10002 is valid
# Iteration 10003 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10003.jpg exists
# Picture 10003 is valid
# Iteration 10004 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10004.jpg exists
# Picture 10004 is valid
# Iteration 10005 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10005.jpg exists
#   0%|          | 7/10000 [00:00<15:21, 10.85it/s]
# Picture 10005 is valid
# Iteration 10006 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10006.jpg exists
# Picture 10006 is valid
# Iteration 10007 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10007.jpg exists
# Picture 10007 is valid
# Iteration 10008 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10008.jpg exists
#   0%|          | 9/10000 [00:00<14:59, 11.10it/s]
#   0%|          | 11/10000 [00:00<14:28, 11.50it/s]
# Picture 10008 is valid
# Iteration 10009 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10009.jpg exists
# Picture 10009 is valid
# Iteration 10010 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10010.jpg exists
# Picture 10010 is valid
# Iteration 10011 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10011.jpg exists
#   0%|          | 13/10000 [00:01<14:31, 11.46it/s]
# Picture 10011 is valid
# Iteration 10012 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10012.jpg exists
# Picture 10012 is valid
# Iteration 10013 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10013.jpg exists
# Picture 10013 is valid
# Iteration 10014 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10014.jpg exists
#   0%|          | 15/10000 [00:01<14:26, 11.53it/s]
#   0%|          | 17/10000 [00:01<14:18, 11.63it/s]
# Picture 10014 is valid
# Iteration 10015 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10015.jpg exists
# Picture 10015 is valid
# Iteration 10016 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10016.jpg exists
# Picture 10016 is valid
# Iteration 10017 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10017.jpg exists
#   0%|          | 19/10000 [00:01<14:19, 11.61it/s]
# Picture 10017 is valid
# Iteration 10018 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10018.jpg exists
# Picture 10018 is valid
# Iteration 10019 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10019.jpg exists
# Picture 10019 is valid
# Iteration 10020 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10020.jpg exists
#   0%|          | 21/10000 [00:01<14:17, 11.63it/s]
#   0%|          | 23/10000 [00:01<14:06, 11.79it/s]
# Picture 10020 is valid
# Iteration 10021 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10021.jpg exists
# Picture 10021 is valid
# Iteration 10022 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10022.jpg exists
# Picture 10022 is valid
# Iteration 10023 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10023.jpg exists
#   0%|          | 25/10000 [00:02<15:12, 10.93it/s]
# Picture 10023 is valid
# Iteration 10024 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10024.jpg exists
# Picture 10024 is valid
# Iteration 10025 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10025.jpg exists
# Picture 10025 is valid
# Iteration 10026 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10026.jpg exists
#   0%|          | 27/10000 [00:02<14:42, 11.31it/s]
#   0%|          | 29/10000 [00:02<14:23, 11.54it/s]
# Picture 10026 is valid
# Iteration 10027 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10027.jpg exists
# Picture 10027 is valid
# Iteration 10028 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10028.jpg exists
# Picture 10028 is valid
# Iteration 10029 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10029.jpg exists
#   0%|          | 31/10000 [00:02<14:47, 11.23it/s]
# Picture 10029 is valid
# Iteration 10030 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10030.jpg exists
# Picture 10030 is valid
# Iteration 10031 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10031.jpg exists
# Picture 10031 is valid
# Iteration 10032 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10032.jpg exists
#   0%|          | 33/10000 [00:02<14:35, 11.38it/s]
#   0%|          | 35/10000 [00:03<14:23, 11.53it/s]
# Picture 10032 is valid
# Iteration 10033 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10033.jpg exists
# Picture 10033 is valid
# Iteration 10034 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10034.jpg exists
# Picture 10034 is valid
# Iteration 10035 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10035.jpg exists
#   0%|          | 37/10000 [00:03<14:16, 11.63it/s]
# Picture 10035 is valid
# Iteration 10036 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10036.jpg exists
# Picture 10036 is valid
# Iteration 10037 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10037.jpg exists
# Picture 10037 is valid
# Iteration 10038 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10038.jpg exists
#   0%|          | 39/10000 [00:03<14:01, 11.84it/s]
#   0%|          | 41/10000 [00:03<13:56, 11.90it/s]
# Picture 10038 is valid
# Iteration 10039 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10039.jpg exists
# Picture 10039 is valid
# Iteration 10040 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10040.jpg exists
# Picture 10040 is valid
# Iteration 10041 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10041.jpg exists
#   0%|          | 43/10000 [00:03<13:52, 11.96it/s]
# Picture 10041 is valid
# Iteration 10042 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10042.jpg exists
# Picture 10042 is valid
# Iteration 10043 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10043.jpg exists
# Picture 10043 is valid
# Iteration 10044 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10044.jpg exists
#   0%|          | 45/10000 [00:03<13:55, 11.91it/s]
#   0%|          | 47/10000 [00:04<13:50, 11.99it/s]
# Picture 10044 is valid
# Iteration 10045 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10045.jpg exists
# Picture 10045 is valid
# Iteration 10046 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10046.jpg exists
# Picture 10046 is valid
# Iteration 10047 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10047.jpg exists
#   0%|          | 49/10000 [00:04<15:06, 10.98it/s]
# Picture 10047 is valid
# Iteration 10048 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10048.jpg exists
# Picture 10048 is valid
# Iteration 10049 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10049.jpg exists
# Picture 10049 is valid
# Iteration 10050 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10050.jpg exists
#   1%|          | 51/10000 [00:04<14:41, 11.29it/s]
#   1%|          | 53/10000 [00:04<14:41, 11.29it/s]
# Picture 10050 is valid
# Iteration 10051 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10051.jpg exists
# Picture 10051 is valid
# Iteration 10052 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10052.jpg exists
# Picture 10052 is valid
# Iteration 10053 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10053.jpg exists
#   1%|          | 55/10000 [00:04<14:22, 11.53it/s]
# Picture 10053 is valid
# Iteration 10054 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10054.jpg exists
# Picture 10054 is valid
# Iteration 10055 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10055.jpg exists
# Picture 10055 is valid
# Iteration 10056 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10056.jpg exists
#   1%|          | 57/10000 [00:04<14:05, 11.76it/s]
#   1%|          | 59/10000 [00:05<13:57, 11.87it/s]
# Picture 10056 is valid
# Iteration 10057 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10057.jpg exists
# Picture 10057 is valid
# Iteration 10058 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10058.jpg exists
# Picture 10058 is valid
# Iteration 10059 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10059.jpg exists
#   1%|          | 61/10000 [00:05<13:53, 11.93it/s]
# Picture 10059 is valid
# Iteration 10060 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10060.jpg exists
# Picture 10060 is valid
# Iteration 10061 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10061.jpg exists
# Picture 10061 is valid
# Iteration 10062 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10062.jpg exists
#   1%|          | 63/10000 [00:05<13:58, 11.85it/s]
#   1%|          | 65/10000 [00:05<13:57, 11.86it/s]
# Picture 10062 is valid
# Iteration 10063 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10063.jpg exists
# Picture 10063 is valid
# Iteration 10064 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10064.jpg exists
# Picture 10064 is valid
# Iteration 10065 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10065.jpg exists
#   1%|          | 67/10000 [00:05<14:05, 11.75it/s]
# Picture 10065 is valid
# Iteration 10066 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10066.jpg exists
# Iteration 10067 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10067.jpg exists
# Picture 10067 is valid
# Iteration 10068 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10068.jpg exists
# Picture 10068 is valid
# Iteration 10069 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10069.jpg exists
#   1%|          | 69/10000 [00:05<13:56, 11.88it/s]
# Picture 10069 is valid
# Iteration 10070 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10070.jpg exists
# Picture 10070 is valid
# Iteration 10071 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10071.jpg exists
#   1%|          | 71/10000 [00:06<15:01, 11.01it/s]
#   1%|          | 73/10000 [00:06<14:40, 11.28it/s]
# Picture 10071 is valid
# Iteration 10072 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10072.jpg exists
# Picture 10072 is valid
# Iteration 10073 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10073.jpg exists
# Picture 10073 is valid
# Iteration 10074 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10074.jpg exists
#   1%|          | 75/10000 [00:06<14:22, 11.50it/s]
# Picture 10074 is valid
# Iteration 10075 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10075.jpg exists
# Picture 10075 is valid
# Iteration 10076 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10076.jpg exists
# Picture 10076 is valid
# Iteration 10077 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10077.jpg exists
#   1%|          | 77/10000 [00:06<14:14, 11.62it/s]
#   1%|          | 79/10000 [00:06<14:16, 11.59it/s]
# Picture 10077 is valid
# Iteration 10078 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10078.jpg exists
# Picture 10078 is valid
# Iteration 10079 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10079.jpg exists
# Picture 10079 is valid
# Iteration 10080 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10080.jpg exists
#   1%|          | 81/10000 [00:06<14:10, 11.67it/s]
# Picture 10080 is valid
# Iteration 10081 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10081.jpg exists
# Picture 10081 is valid
# Iteration 10082 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10082.jpg exists
# Picture 10082 is valid
# Iteration 10083 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10083.jpg exists
#   1%|          | 83/10000 [00:07<14:18, 11.55it/s]
#   1%|          | 85/10000 [00:07<14:12, 11.63it/s]
# Picture 10083 is valid
# Iteration 10084 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10084.jpg exists
# Picture 10084 is valid
# Iteration 10085 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10085.jpg exists
# Picture 10085 is valid
# Iteration 10086 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10086.jpg exists
#   1%|          | 87/10000 [00:07<14:10, 11.65it/s]
# Picture 10086 is valid
# Iteration 10087 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10087.jpg exists
# Picture 10087 is valid
# Iteration 10088 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10088.jpg exists
# Picture 10088 is valid
# Iteration 10089 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10089.jpg exists
#   1%|          | 89/10000 [00:07<14:12, 11.63it/s]
#   1%|          | 91/10000 [00:07<13:56, 11.84it/s]
# Picture 10089 is valid
# Iteration 10090 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10090.jpg exists
# Picture 10090 is valid
# Iteration 10091 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10091.jpg exists
# Picture 10091 is valid
# Iteration 10092 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10092.jpg exists
#   1%|          | 93/10000 [00:07<13:48, 11.96it/s]
# Picture 10092 is valid
# Iteration 10093 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10093.jpg exists
# Picture 10093 is valid
# Iteration 10094 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10094.jpg exists
#   1%|          | 95/10000 [00:08<15:08, 10.90it/s]
# Picture 10094 is valid
# Iteration 10095 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10095.jpg exists
# Picture 10095 is valid
# Iteration 10096 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10096.jpg exists
# Picture 10096 is valid
# Iteration 10097 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10097.jpg exists
#   1%|          | 97/10000 [00:08<14:35, 11.31it/s]
#   1%|          | 99/10000 [00:08<14:18, 11.54it/s]
# Picture 10097 is valid
# Iteration 10098 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10098.jpg exists
# Picture 10098 is valid
# Iteration 10099 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10099.jpg exists
# Picture 10099 is valid
# Iteration 10100 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10100.jpg exists
#   1%|          | 101/10000 [00:08<14:20, 11.50it/s]
# Picture 10100 is valid
# Iteration 10101 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10101.jpg exists
# Picture 10101 is valid
# Iteration 10102 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10102.jpg exists
# Picture 10102 is valid
# Iteration 10103 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10103.jpg exists
#   1%|          | 103/10000 [00:08<14:24, 11.45it/s]
#   1%|          | 105/10000 [00:09<14:03, 11.73it/s]
# Picture 10103 is valid
# Iteration 10104 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10104.jpg exists
# Picture 10104 is valid
# Iteration 10105 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10105.jpg exists
# Picture 10105 is valid
# Iteration 10106 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10106.jpg exists
#   1%|          | 107/10000 [00:09<13:53, 11.87it/s]
# Picture 10106 is valid
# Iteration 10107 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10107.jpg exists
# Picture 10107 is valid
# Iteration 10108 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10108.jpg exists
# Picture 10108 is valid
# Iteration 10109 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10109.jpg exists
#   1%|          | 109/10000 [00:09<13:42, 12.03it/s]
#   1%|          | 111/10000 [00:09<13:44, 11.99it/s]
# Picture 10109 is valid
# Iteration 10110 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10110.jpg exists
# Picture 10110 is valid
# Iteration 10111 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10111.jpg exists
# Picture 10111 is valid
# Iteration 10112 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10112.jpg exists
#   1%|          | 113/10000 [00:09<13:41, 12.04it/s]
# Picture 10112 is valid
# Iteration 10113 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10113.jpg exists
# Picture 10113 is valid
# Iteration 10114 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10114.jpg exists
# Picture 10114 is valid
# Iteration 10115 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10115.jpg exists
#   1%|          | 115/10000 [00:09<13:47, 11.95it/s]
#   1%|          | 117/10000 [00:10<14:03, 11.71it/s]
# Picture 10115 is valid
# Iteration 10116 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10116.jpg exists
# Picture 10116 is valid
# Iteration 10117 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10117.jpg exists
# Picture 10117 is valid
# Iteration 10118 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10118.jpg exists
#   1%|          | 119/10000 [00:10<14:33, 11.32it/s]
# Picture 10118 is valid
# Iteration 10119 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10119.jpg exists
# Picture 10119 is valid
# Iteration 10120 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10120.jpg exists
# Picture 10120 is valid
# Iteration 10121 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10121.jpg exists
#   1%|          | 121/10000 [00:10<14:26, 11.40it/s]
#   1%|          | 123/10000 [00:10<14:12, 11.58it/s]
# Picture 10121 is valid
# Iteration 10122 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10122.jpg exists
# Picture 10122 is valid
# Iteration 10123 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10123.jpg exists
# Picture 10123 is valid
# Iteration 10124 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10124.jpg exists
#   1%|▏         | 125/10000 [00:10<14:06, 11.67it/s]
# Picture 10124 is valid
# Iteration 10125 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10125.jpg exists
# Picture 10125 is valid
# Iteration 10126 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10126.jpg exists
# Picture 10126 is valid
# Iteration 10127 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10127.jpg exists
#   1%|▏         | 127/10000 [00:10<14:03, 11.70it/s]
#   1%|▏         | 129/10000 [00:11<13:50, 11.88it/s]
# Picture 10127 is valid
# Iteration 10128 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10128.jpg exists
# Picture 10128 is valid
# Iteration 10129 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10129.jpg exists
# Picture 10129 is valid
# Iteration 10130 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10130.jpg exists
#   1%|▏         | 131/10000 [00:11<13:41, 12.02it/s]
# Picture 10130 is valid
# Iteration 10131 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10131.jpg exists
# Picture 10131 is valid
# Iteration 10132 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10132.jpg exists
# Picture 10132 is valid
# Iteration 10133 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10133.jpg exists
#   1%|▏         | 133/10000 [00:11<13:43, 11.98it/s]
#   1%|▏         | 135/10000 [00:11<13:50, 11.88it/s]
# Picture 10133 is valid
# Iteration 10134 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10134.jpg exists
# Iteration 10135 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10135.jpg exists
# Picture 10135 is valid
# Iteration 10136 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10136.jpg exists
# Picture 10136 is valid
# Iteration 10137 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10137.jpg exists
#   1%|▏         | 137/10000 [00:11<14:01, 11.72it/s]
# Picture 10137 is valid
# Iteration 10138 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10138.jpg exists
# Picture 10138 is valid
# Iteration 10139 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10139.jpg exists
# Picture 10139 is valid
# Iteration 10140 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10140.jpg exists
#   1%|▏         | 139/10000 [00:11<13:52, 11.85it/s]
# Picture 10140 is valid
# Iteration 10141 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10141.jpg exists
# Picture 10141 is valid
# Iteration 10142 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10142.jpg exists
#   1%|▏         | 141/10000 [00:12<14:55, 11.01it/s]
#   1%|▏         | 143/10000 [00:12<14:21, 11.44it/s]
# Picture 10142 is valid
# Iteration 10143 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10143.jpg exists
# Picture 10143 is valid
# Iteration 10144 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10144.jpg exists
# Picture 10144 is valid
# Iteration 10145 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10145.jpg exists
#   1%|▏         | 145/10000 [00:12<14:09, 11.60it/s]
# Picture 10145 is valid
# Iteration 10146 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10146.jpg exists
# Picture 10146 is valid
# Iteration 10147 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10147.jpg exists
# Picture 10147 is valid
# Iteration 10148 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10148.jpg exists
#   1%|▏         | 147/10000 [00:12<14:06, 11.64it/s]
#   1%|▏         | 149/10000 [00:12<14:03, 11.68it/s]
# Picture 10148 is valid
# Iteration 10149 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10149.jpg exists
# Iteration 10150 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10150.jpg exists
# Picture 10150 is valid
# Iteration 10151 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10151.jpg exists
# Picture 10151 is valid
# Iteration 10152 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10152.jpg exists
#   2%|▏         | 151/10000 [00:12<14:00, 11.72it/s]
# Picture 10152 is valid
# Iteration 10153 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10153.jpg exists
# Picture 10153 is valid
# Iteration 10154 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10154.jpg exists
# Picture 10154 is valid
# Iteration 10155 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10155.jpg exists
#   2%|▏         | 153/10000 [00:13<13:59, 11.73it/s]
#   2%|▏         | 155/10000 [00:13<13:55, 11.78it/s]
# Picture 10155 is valid
# Iteration 10156 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10156.jpg exists
# Picture 10156 is valid
# Iteration 10157 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10157.jpg exists
# Picture 10157 is valid
# Iteration 10158 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10158.jpg exists
#   2%|▏         | 157/10000 [00:13<13:54, 11.80it/s]
# Picture 10158 is valid
# Iteration 10159 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10159.jpg exists
# Picture 10159 is valid
# Iteration 10160 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10160.jpg exists
# Picture 10160 is valid
# Iteration 10161 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10161.jpg exists
#   2%|▏         | 159/10000 [00:13<13:59, 11.72it/s]
#   2%|▏         | 161/10000 [00:13<13:50, 11.84it/s]
# Picture 10161 is valid
# Iteration 10162 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10162.jpg exists
# Picture 10162 is valid
# Iteration 10163 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10163.jpg exists
# Picture 10163 is valid
# Iteration 10164 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10164.jpg exists
#   2%|▏         | 163/10000 [00:14<14:21, 11.42it/s]
# Picture 10164 is valid
# Iteration 10165 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10165.jpg exists
# Picture 10165 is valid
# Iteration 10166 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10166.jpg exists
#   2%|▏         | 165/10000 [00:14<15:13, 10.76it/s]
# Picture 10166 is valid
# Iteration 10167 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10167.jpg exists
# Picture 10167 is valid
# Iteration 10168 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10168.jpg exists
# Iteration 10169 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10169.jpg exists
# Picture 10169 is valid
# Iteration 10170 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10170.jpg exists
#   2%|▏         | 167/10000 [00:14<15:01, 10.91it/s]
#   2%|▏         | 169/10000 [00:14<14:28, 11.32it/s]
# Picture 10170 is valid
# Iteration 10171 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10171.jpg exists
# Picture 10171 is valid
# Iteration 10172 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10172.jpg exists
# Picture 10172 is valid
# Iteration 10173 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10173.jpg exists
#   2%|▏         | 171/10000 [00:14<14:32, 11.26it/s]
# Picture 10173 is valid
# Iteration 10174 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10174.jpg exists
# Picture 10174 is valid
# Iteration 10175 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10175.jpg exists
# Picture 10175 is valid
# Iteration 10176 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10176.jpg exists
#   2%|▏         | 173/10000 [00:14<14:15, 11.48it/s]
#   2%|▏         | 175/10000 [00:15<13:54, 11.78it/s]
# Picture 10176 is valid
# Iteration 10177 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10177.jpg exists
# Picture 10177 is valid
# Iteration 10178 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10178.jpg exists
# Picture 10178 is valid
# Iteration 10179 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10179.jpg exists
#   2%|▏         | 177/10000 [00:15<13:55, 11.76it/s]
# Picture 10179 is valid
# Iteration 10180 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10180.jpg exists
# Picture 10180 is valid
# Iteration 10181 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10181.jpg exists
# Picture 10181 is valid
# Iteration 10182 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10182.jpg exists
#   2%|▏         | 179/10000 [00:15<13:52, 11.80it/s]
#   2%|▏         | 181/10000 [00:15<13:39, 11.98it/s]
# Picture 10182 is valid
# Iteration 10183 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10183.jpg exists
# Picture 10183 is valid
# Iteration 10184 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10184.jpg exists
# Picture 10184 is valid
# Iteration 10185 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10185.jpg exists
#   2%|▏         | 183/10000 [00:15<13:38, 12.00it/s]
# Picture 10185 is valid
# Iteration 10186 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10186.jpg exists
# Picture 10186 is valid
# Iteration 10187 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10187.jpg exists
# Picture 10187 is valid
# Iteration 10188 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10188.jpg exists
#   2%|▏         | 185/10000 [00:15<13:42, 11.93it/s]
# Picture 10188 is valid
# Iteration 10189 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10189.jpg exists
# Picture 10189 is valid
# Iteration 10190 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10190.jpg exists
#   2%|▏         | 187/10000 [00:16<15:04, 10.85it/s]
#   2%|▏         | 189/10000 [00:16<14:38, 11.17it/s]
# Picture 10190 is valid
# Iteration 10191 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10191.jpg exists
# Picture 10191 is valid
# Iteration 10192 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10192.jpg exists
# Picture 10192 is valid
# Iteration 10193 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10193.jpg exists
#   2%|▏         | 191/10000 [00:16<14:14, 11.49it/s]
# Picture 10193 is valid
# Iteration 10194 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10194.jpg exists
# Picture 10194 is valid
# Iteration 10195 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10195.jpg exists
# Picture 10195 is valid
# Iteration 10196 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10196.jpg exists
#   2%|▏         | 193/10000 [00:16<14:19, 11.41it/s]
#   2%|▏         | 195/10000 [00:16<14:04, 11.61it/s]
# Picture 10196 is valid
# Iteration 10197 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10197.jpg exists
# Picture 10197 is valid
# Iteration 10198 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10198.jpg exists
# Picture 10198 is valid
# Iteration 10199 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10199.jpg exists
#   2%|▏         | 197/10000 [00:16<13:54, 11.75it/s]
# Picture 10199 is valid
# Iteration 10200 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10200.jpg exists
# Picture 10200 is valid
# Iteration 10201 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10201.jpg exists
# Picture 10201 is valid
# Iteration 10202 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10202.jpg exists
#   2%|▏         | 199/10000 [00:17<13:53, 11.76it/s]
#   2%|▏         | 201/10000 [00:17<13:40, 11.95it/s]
# Picture 10202 is valid
# Iteration 10203 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10203.jpg exists
# Picture 10203 is valid
# Iteration 10204 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10204.jpg exists
# Picture 10204 is valid
# Iteration 10205 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10205.jpg exists
#   2%|▏         | 203/10000 [00:17<13:38, 11.97it/s]
# Picture 10205 is valid
# Iteration 10206 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10206.jpg exists
# Picture 10206 is valid
# Iteration 10207 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10207.jpg exists
# Picture 10207 is valid
# Iteration 10208 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10208.jpg exists
#   2%|▏         | 205/10000 [00:17<13:41, 11.93it/s]
#   2%|▏         | 207/10000 [00:17<13:44, 11.88it/s]
# Picture 10208 is valid
# Iteration 10209 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10209.jpg exists
# Iteration 10210 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10210.jpg exists
# Picture 10210 is valid
# Iteration 10211 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10211.jpg exists
# Picture 10211 is valid
# Iteration 10212 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10212.jpg exists
#   2%|▏         | 209/10000 [00:17<13:58, 11.68it/s]
# Picture 10212 is valid
# Iteration 10213 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10213.jpg exists
# Picture 10213 is valid
# Iteration 10214 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10214.jpg exists
#   2%|▏         | 211/10000 [00:18<15:07, 10.79it/s]
# Picture 10214 is valid
# Iteration 10215 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10215.jpg exists
# Picture 10215 is valid
# Iteration 10216 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10216.jpg exists
# Picture 10216 is valid
# Iteration 10217 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10217.jpg exists
#   2%|▏         | 213/10000 [00:18<14:50, 10.99it/s]
#   2%|▏         | 215/10000 [00:18<15:06, 10.80it/s]
# Picture 10217 is valid
# Iteration 10218 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10218.jpg exists
# Picture 10218 is valid
# Iteration 10219 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10219.jpg exists
# Iteration 10220 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10220.jpg exists
# Picture 10220 is valid
# Iteration 10221 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10221.jpg exists
#   2%|▏         | 217/10000 [00:18<14:54, 10.93it/s]
# Picture 10221 is valid
# Iteration 10222 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10222.jpg exists
# Picture 10222 is valid
# Iteration 10223 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10223.jpg exists
# Picture 10223 is valid
# Iteration 10224 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10224.jpg exists
#   2%|▏         | 219/10000 [00:18<14:54, 10.93it/s]
#   2%|▏         | 221/10000 [00:19<14:40, 11.11it/s]
# Picture 10224 is valid
# Iteration 10225 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10225.jpg exists
# Picture 10225 is valid
# Iteration 10226 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10226.jpg exists
# Picture 10226 is valid
# Iteration 10227 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10227.jpg exists
#   2%|▏         | 223/10000 [00:19<14:19, 11.38it/s]
# Picture 10227 is valid
# Iteration 10228 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10228.jpg exists
# Picture 10228 is valid
# Iteration 10229 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10229.jpg exists
# Picture 10229 is valid
# Iteration 10230 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10230.jpg exists
#   2%|▏         | 225/10000 [00:19<14:03, 11.60it/s]
#   2%|▏         | 227/10000 [00:19<13:49, 11.78it/s]
# Picture 10230 is valid
# Iteration 10231 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10231.jpg exists
# Picture 10231 is valid
# Iteration 10232 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10232.jpg exists
# Picture 10232 is valid
# Iteration 10233 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10233.jpg exists
#   2%|▏         | 229/10000 [00:19<13:36, 11.96it/s]
# Picture 10233 is valid
# Iteration 10234 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10234.jpg exists
# Picture 10234 is valid
# Iteration 10235 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10235.jpg exists
# Picture 10235 is valid
# Iteration 10236 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10236.jpg exists
#   2%|▏         | 231/10000 [00:19<13:26, 12.12it/s]
# Picture 10236 is valid
# Iteration 10237 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10237.jpg exists
# Picture 10237 is valid
# Iteration 10238 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10238.jpg exists
#   2%|▏         | 233/10000 [00:20<14:45, 11.03it/s]
#   2%|▏         | 235/10000 [00:20<14:15, 11.41it/s]
# Picture 10238 is valid
# Iteration 10239 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10239.jpg exists
# Picture 10239 is valid
# Iteration 10240 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10240.jpg exists
# Picture 10240 is valid
# Iteration 10241 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10241.jpg exists
#   2%|▏         | 237/10000 [00:20<14:00, 11.61it/s]
# Picture 10241 is valid
# Iteration 10242 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10242.jpg exists
# Picture 10242 is valid
# Iteration 10243 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10243.jpg exists
# Picture 10243 is valid
# Iteration 10244 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10244.jpg exists
#   2%|▏         | 239/10000 [00:20<13:49, 11.77it/s]
#   2%|▏         | 241/10000 [00:20<13:41, 11.88it/s]
# Picture 10244 is valid
# Iteration 10245 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10245.jpg exists
# Picture 10245 is valid
# Iteration 10246 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10246.jpg exists
# Picture 10246 is valid
# Iteration 10247 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10247.jpg exists
#   2%|▏         | 243/10000 [00:20<13:38, 11.92it/s]
# Picture 10247 is valid
# Iteration 10248 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10248.jpg exists
# Picture 10248 is valid
# Iteration 10249 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10249.jpg exists
# Picture 10249 is valid
# Iteration 10250 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10250.jpg exists
#   2%|▏         | 245/10000 [00:21<13:30, 12.03it/s]
#   2%|▏         | 247/10000 [00:21<13:26, 12.10it/s]
# Picture 10250 is valid
# Iteration 10251 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10251.jpg exists
# Picture 10251 is valid
# Iteration 10252 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10252.jpg exists
# Picture 10252 is valid
# Iteration 10253 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10253.jpg exists
#   2%|▏         | 249/10000 [00:21<13:24, 12.12it/s]
# Picture 10253 is valid
# Iteration 10254 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10254.jpg exists
# Picture 10254 is valid
# Iteration 10255 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10255.jpg exists
# Picture 10255 is valid
# Iteration 10256 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10256.jpg exists
#   3%|▎         | 251/10000 [00:21<13:41, 11.87it/s]
#   3%|▎         | 253/10000 [00:21<13:32, 12.00it/s]
# Picture 10256 is valid
# Iteration 10257 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10257.jpg exists
# Picture 10257 is valid
# Iteration 10258 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10258.jpg exists
# Picture 10258 is valid
# Iteration 10259 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10259.jpg exists
#   3%|▎         | 255/10000 [00:21<13:35, 11.94it/s]
# Picture 10259 is valid
# Iteration 10260 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10260.jpg exists
# Picture 10260 is valid
# Iteration 10261 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10261.jpg exists
# Picture 10261 is valid
# Iteration 10262 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10262.jpg exists
#   3%|▎         | 257/10000 [00:22<14:37, 11.10it/s]
#   3%|▎         | 259/10000 [00:22<14:14, 11.40it/s]
# Picture 10262 is valid
# Iteration 10263 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10263.jpg exists
# Picture 10263 is valid
# Iteration 10264 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10264.jpg exists
# Picture 10264 is valid
# Iteration 10265 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10265.jpg exists
#   3%|▎         | 261/10000 [00:22<14:01, 11.58it/s]
# Picture 10265 is valid
# Iteration 10266 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10266.jpg exists
# Picture 10266 is valid
# Iteration 10267 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10267.jpg exists
# Picture 10267 is valid
# Iteration 10268 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10268.jpg exists
#   3%|▎         | 263/10000 [00:22<14:16, 11.37it/s]
#   3%|▎         | 265/10000 [00:22<14:06, 11.51it/s]
# Picture 10268 is valid
# Iteration 10269 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10269.jpg exists
# Picture 10269 is valid
# Iteration 10270 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10270.jpg exists
# Picture 10270 is valid
# Iteration 10271 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10271.jpg exists
#   3%|▎         | 267/10000 [00:23<14:11, 11.43it/s]
# Picture 10271 is valid
# Iteration 10272 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10272.jpg exists
# Picture 10272 is valid
# Iteration 10273 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10273.jpg exists
# Picture 10273 is valid
# Iteration 10274 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10274.jpg exists
#   3%|▎         | 269/10000 [00:23<14:11, 11.43it/s]
#   3%|▎         | 271/10000 [00:23<14:22, 11.27it/s]
# Picture 10274 is valid
# Iteration 10275 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10275.jpg exists
# Picture 10275 is valid
# Iteration 10276 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10276.jpg exists
# Iteration 10277 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10277.jpg exists
# Picture 10277 is valid
# Iteration 10278 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10278.jpg exists
#   3%|▎         | 273/10000 [00:23<14:16, 11.36it/s]
# Picture 10278 is valid
# Iteration 10279 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10279.jpg exists
# Picture 10279 is valid
# Iteration 10280 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10280.jpg exists
# Picture 10280 is valid
# Iteration 10281 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10281.jpg exists
#   3%|▎         | 275/10000 [00:23<14:19, 11.32it/s]
#   3%|▎         | 277/10000 [00:23<14:28, 11.20it/s]
# Picture 10281 is valid
# Iteration 10282 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10282.jpg exists
# Picture 10282 is valid
# Iteration 10283 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10283.jpg exists
# Picture 10283 is valid
# Iteration 10284 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10284.jpg exists
#   3%|▎         | 279/10000 [00:24<15:43, 10.30it/s]
# Picture 10284 is valid
# Iteration 10285 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10285.jpg exists
# Picture 10285 is valid
# Iteration 10286 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10286.jpg exists
#   3%|▎         | 281/10000 [00:24<15:26, 10.48it/s]
# Picture 10286 is valid
# Iteration 10287 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10287.jpg exists
# Picture 10287 is valid
# Iteration 10288 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10288.jpg exists
# Picture 10288 is valid
# Iteration 10289 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10289.jpg exists
#   3%|▎         | 283/10000 [00:24<15:14, 10.63it/s]
#   3%|▎         | 285/10000 [00:24<15:10, 10.67it/s]
# Picture 10289 is valid
# Iteration 10290 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10290.jpg exists
# Picture 10290 is valid
# Iteration 10291 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10291.jpg exists
# Picture 10291 is valid
# Iteration 10292 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10292.jpg exists
#   3%|▎         | 287/10000 [00:24<15:02, 10.76it/s]
# Picture 10292 is valid
# Iteration 10293 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10293.jpg exists
# Iteration 10294 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10294.jpg exists
# Picture 10294 is valid
# Iteration 10295 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10295.jpg exists
# Picture 10295 is valid
# Iteration 10296 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10296.jpg exists
#   3%|▎         | 289/10000 [00:25<14:46, 10.96it/s]
#   3%|▎         | 291/10000 [00:25<14:16, 11.33it/s]
# Picture 10296 is valid
# Iteration 10297 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10297.jpg exists
# Picture 10297 is valid
# Iteration 10298 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10298.jpg exists
# Picture 10298 is valid
# Iteration 10299 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10299.jpg exists
#   3%|▎         | 293/10000 [00:25<14:00, 11.55it/s]
# Picture 10299 is valid
# Iteration 10300 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10300.jpg exists
# Picture 10300 is valid
# Iteration 10301 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10301.jpg exists
# Picture 10301 is valid
# Iteration 10302 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10302.jpg exists
#   3%|▎         | 295/10000 [00:25<13:57, 11.59it/s]
#   3%|▎         | 297/10000 [00:25<13:42, 11.80it/s]
# Picture 10302 is valid
# Iteration 10303 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10303.jpg exists
# Picture 10303 is valid
# Iteration 10304 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10304.jpg exists
# Picture 10304 is valid
# Iteration 10305 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10305.jpg exists
#   3%|▎         | 299/10000 [00:25<13:37, 11.87it/s]
# Picture 10305 is valid
# Iteration 10306 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10306.jpg exists
# Picture 10306 is valid
# Iteration 10307 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10307.jpg exists
# Picture 10307 is valid
# Iteration 10308 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10308.jpg exists
#   3%|▎         | 301/10000 [00:26<13:34, 11.90it/s]
#   3%|▎         | 303/10000 [00:26<14:21, 11.25it/s]
# Picture 10308 is valid
# Iteration 10309 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10309.jpg exists
# Picture 10309 is valid
# Iteration 10310 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10310.jpg exists
#   3%|▎         | 305/10000 [00:26<14:04, 11.48it/s]
# Picture 10310 is valid
# Iteration 10311 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10311.jpg exists
# Picture 10311 is valid
# Iteration 10312 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10312.jpg exists
# Picture 10312 is valid
# Iteration 10313 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10313.jpg exists
#   3%|▎         | 307/10000 [00:26<13:55, 11.60it/s]
# Picture 10313 is valid
# Iteration 10314 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10314.jpg exists
# Picture 10314 is valid
# Iteration 10315 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10315.jpg exists
# Picture 10315 is valid
# Iteration 10316 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10316.jpg exists
#   3%|▎         | 309/10000 [00:26<13:55, 11.60it/s]
#   3%|▎         | 311/10000 [00:26<13:46, 11.72it/s]
# Picture 10316 is valid
# Iteration 10317 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10317.jpg exists
# Picture 10317 is valid
# Iteration 10318 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10318.jpg exists
# Picture 10318 is valid
# Iteration 10319 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10319.jpg exists
#   3%|▎         | 313/10000 [00:27<13:58, 11.56it/s]
# Picture 10319 is valid
# Iteration 10320 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10320.jpg exists
# Picture 10320 is valid
# Iteration 10321 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10321.jpg exists
# Picture 10321 is valid
# Iteration 10322 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10322.jpg exists
#   3%|▎         | 315/10000 [00:27<13:46, 11.71it/s]
#   3%|▎         | 317/10000 [00:27<13:35, 11.87it/s]
# Picture 10322 is valid
# Iteration 10323 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10323.jpg exists
# Picture 10323 is valid
# Iteration 10324 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10324.jpg exists
# Picture 10324 is valid
# Iteration 10325 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10325.jpg exists
#   3%|▎         | 319/10000 [00:27<13:38, 11.83it/s]
# Picture 10325 is valid
# Iteration 10326 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10326.jpg exists
# Picture 10326 is valid
# Iteration 10327 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10327.jpg exists
# Picture 10327 is valid
# Iteration 10328 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10328.jpg exists
#   3%|▎         | 321/10000 [00:27<13:34, 11.88it/s]
#   3%|▎         | 323/10000 [00:27<13:28, 11.96it/s]
# Picture 10328 is valid
# Iteration 10329 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10329.jpg exists
# Picture 10329 is valid
# Iteration 10330 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10330.jpg exists
# Picture 10330 is valid
# Iteration 10331 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10331.jpg exists
#   3%|▎         | 325/10000 [00:28<14:37, 11.03it/s]
# Picture 10331 is valid
# Iteration 10332 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10332.jpg exists
# Picture 10332 is valid
# Iteration 10333 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10333.jpg exists
#   3%|▎         | 327/10000 [00:28<14:07, 11.42it/s]
# Picture 10333 is valid
# Iteration 10334 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10334.jpg exists
# Picture 10334 is valid
# Iteration 10335 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10335.jpg exists
# Picture 10335 is valid
# Iteration 10336 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10336.jpg exists
#   3%|▎         | 329/10000 [00:28<14:01, 11.50it/s]
#   3%|▎         | 331/10000 [00:28<13:57, 11.55it/s]
# Picture 10336 is valid
# Iteration 10337 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10337.jpg exists
# Picture 10337 is valid
# Iteration 10338 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10338.jpg exists
# Picture 10338 is valid
# Iteration 10339 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10339.jpg exists
#   3%|▎         | 333/10000 [00:28<13:47, 11.68it/s]
# Picture 10339 is valid
# Iteration 10340 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10340.jpg exists
# Picture 10340 is valid
# Iteration 10341 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10341.jpg exists
# Picture 10341 is valid
# Iteration 10342 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/10342.jpg exists
#   3%|▎         | 335/10000 [00:28<13:48, 11.67it/s]
# ...
# Picture 19886 is valid
# Iteration 19887 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19887.jpg exists
#  95%|█████████▌| 9548/10000 [13:51<00:42, 10.68it/s]
#  96%|█████████▌| 9550/10000 [13:51<00:40, 11.05it/s]
# Picture 19887 is valid
# Iteration 19888 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19888.jpg exists
# Picture 19888 is valid
# Iteration 19889 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19889.jpg exists
# Picture 19889 is valid
# Iteration 19890 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19890.jpg exists
#  96%|█████████▌| 9552/10000 [13:51<00:39, 11.40it/s]
# Picture 19890 is valid
# Iteration 19891 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19891.jpg exists
# Picture 19891 is valid
# Iteration 19892 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19892.jpg exists
# Picture 19892 is valid
# Iteration 19893 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19893.jpg exists
#  96%|█████████▌| 9554/10000 [13:52<00:38, 11.52it/s]
#  96%|█████████▌| 9556/10000 [13:52<00:37, 11.80it/s]
# Picture 19893 is valid
# Iteration 19894 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19894.jpg exists
# Picture 19894 is valid
# Iteration 19895 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19895.jpg exists
# Picture 19895 is valid
# Iteration 19896 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19896.jpg exists
#  96%|█████████▌| 9558/10000 [13:52<00:40, 11.00it/s]
# Picture 19896 is valid
# Iteration 19897 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19897.jpg exists
# Picture 19897 is valid
# Iteration 19898 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19898.jpg exists
# Picture 19898 is valid
# Iteration 19899 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19899.jpg exists
#  96%|█████████▌| 9560/10000 [13:52<00:38, 11.30it/s]
# Picture 19899 is valid
# Iteration 19900 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19900.jpg exists
# Picture 19900 is valid
# Iteration 19901 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19901.jpg exists
#  96%|█████████▌| 9562/10000 [13:52<00:37, 11.57it/s]
#  96%|█████████▌| 9564/10000 [13:52<00:37, 11.73it/s]
# Picture 19901 is valid
# Iteration 19902 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19902.jpg exists
# Picture 19902 is valid
# Iteration 19903 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19903.jpg exists
# Iteration 19904 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19904.jpg exists
# Picture 19904 is valid
# Iteration 19905 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19905.jpg exists
#  96%|█████████▌| 9566/10000 [13:53<00:37, 11.54it/s]
# Picture 19905 is valid
# Iteration 19906 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19906.jpg exists
# Picture 19906 is valid
# Iteration 19907 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19907.jpg exists
# Picture 19907 is valid
# Iteration 19908 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19908.jpg exists
#  96%|█████████▌| 9568/10000 [13:53<00:36, 11.76it/s]
#  96%|█████████▌| 9570/10000 [13:53<00:36, 11.92it/s]
# Picture 19908 is valid
# Iteration 19909 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19909.jpg exists
# Picture 19909 is valid
# Iteration 19910 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19910.jpg exists
# Picture 19910 is valid
# Iteration 19911 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19911.jpg exists
#  96%|█████████▌| 9572/10000 [13:53<00:35, 11.94it/s]
# Picture 19911 is valid
# Iteration 19912 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19912.jpg exists
# Picture 19912 is valid
# Iteration 19913 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19913.jpg exists
# Picture 19913 is valid
# Iteration 19914 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19914.jpg exists
#  96%|█████████▌| 9574/10000 [13:53<00:35, 11.95it/s]
#  96%|█████████▌| 9576/10000 [13:53<00:34, 12.15it/s]
# Picture 19914 is valid
# Iteration 19915 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19915.jpg exists
# Picture 19915 is valid
# Iteration 19916 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19916.jpg exists
# Picture 19916 is valid
# Iteration 19917 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19917.jpg exists
#  96%|█████████▌| 9578/10000 [13:54<00:35, 11.79it/s]
# Picture 19917 is valid
# Iteration 19918 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19918.jpg exists
# Iteration 19919 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19919.jpg exists
# Picture 19919 is valid
# Iteration 19920 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19920.jpg exists
# Picture 19920 is valid
# Iteration 19921 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19921.jpg exists
#  96%|█████████▌| 9580/10000 [13:54<00:35, 11.91it/s]
# Picture 19921 is valid
# Iteration 19922 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19922.jpg exists
# Picture 19922 is valid
# Iteration 19923 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19923.jpg exists
#  96%|█████████▌| 9582/10000 [13:54<00:38, 10.94it/s]
#  96%|█████████▌| 9584/10000 [13:54<00:36, 11.25it/s]
# Picture 19923 is valid
# Iteration 19924 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19924.jpg exists
# Picture 19924 is valid
# Iteration 19925 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19925.jpg exists
# Picture 19925 is valid
# Iteration 19926 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19926.jpg exists
#  96%|█████████▌| 9586/10000 [13:54<00:36, 11.35it/s]
# Picture 19926 is valid
# Iteration 19927 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19927.jpg exists
# Picture 19927 is valid
# Iteration 19928 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19928.jpg exists
# Picture 19928 is valid
# Iteration 19929 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19929.jpg exists
#  96%|█████████▌| 9588/10000 [13:55<00:35, 11.60it/s]
#  96%|█████████▌| 9590/10000 [13:55<00:35, 11.69it/s]
# Picture 19929 is valid
# Iteration 19930 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19930.jpg exists
# Picture 19930 is valid
# Iteration 19931 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19931.jpg exists
# Picture 19931 is valid
# Iteration 19932 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19932.jpg exists
# Iteration 19933 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19933.jpg exists
#  96%|█████████▌| 9592/10000 [13:55<00:35, 11.62it/s]
# Picture 19933 is valid
# Iteration 19934 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19934.jpg exists
# Picture 19934 is valid
# Iteration 19935 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19935.jpg exists
# Picture 19935 is valid
# Iteration 19936 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19936.jpg exists
#  96%|█████████▌| 9594/10000 [13:55<00:35, 11.59it/s]
#  96%|█████████▌| 9596/10000 [13:55<00:34, 11.64it/s]
# Picture 19936 is valid
# Iteration 19937 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19937.jpg exists
# Picture 19937 is valid
# Iteration 19938 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19938.jpg exists
# Picture 19938 is valid
# Iteration 19939 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19939.jpg exists
#  96%|█████████▌| 9598/10000 [13:55<00:35, 11.47it/s]
# Picture 19939 is valid
# Iteration 19940 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19940.jpg exists
# Picture 19940 is valid
# Iteration 19941 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19941.jpg exists
# Picture 19941 is valid
# Iteration 19942 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19942.jpg exists
#  96%|█████████▌| 9600/10000 [13:56<00:34, 11.45it/s]
#  96%|█████████▌| 9602/10000 [13:56<00:34, 11.46it/s]
# Picture 19942 is valid
# Iteration 19943 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19943.jpg exists
# Picture 19943 is valid
# Iteration 19944 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19944.jpg exists
# Picture 19944 is valid
# Iteration 19945 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19945.jpg exists
#  96%|█████████▌| 9604/10000 [13:56<00:37, 10.62it/s]
# Picture 19945 is valid
# Iteration 19946 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19946.jpg exists
# Picture 19946 is valid
# Iteration 19947 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19947.jpg exists
#  96%|█████████▌| 9606/10000 [13:56<00:37, 10.61it/s]
# Picture 19947 is valid
# Iteration 19948 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19948.jpg exists
# Picture 19948 is valid
# Iteration 19949 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19949.jpg exists
# Picture 19949 is valid
# Iteration 19950 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19950.jpg exists
#  96%|█████████▌| 9608/10000 [13:56<00:35, 10.93it/s]
#  96%|█████████▌| 9610/10000 [13:57<00:34, 11.25it/s]
# Picture 19950 is valid
# Iteration 19951 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19951.jpg exists
# Picture 19951 is valid
# Iteration 19952 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19952.jpg exists
# Picture 19952 is valid
# Iteration 19953 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19953.jpg exists
#  96%|█████████▌| 9612/10000 [13:57<00:33, 11.45it/s]
# Picture 19953 is valid
# Iteration 19954 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19954.jpg exists
# Picture 19954 is valid
# Iteration 19955 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19955.jpg exists
# Picture 19955 is valid
# Iteration 19956 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19956.jpg exists
#  96%|█████████▌| 9614/10000 [13:57<00:33, 11.60it/s]
#  96%|█████████▌| 9616/10000 [13:57<00:32, 11.77it/s]
# Picture 19956 is valid
# Iteration 19957 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19957.jpg exists
# Picture 19957 is valid
# Iteration 19958 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19958.jpg exists
# Picture 19958 is valid
# Iteration 19959 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19959.jpg exists
#  96%|█████████▌| 9618/10000 [13:57<00:32, 11.89it/s]
# Picture 19959 is valid
# Iteration 19960 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19960.jpg exists
# Picture 19960 is valid
# Iteration 19961 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19961.jpg exists
# Picture 19961 is valid
# Iteration 19962 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19962.jpg exists
#  96%|█████████▌| 9620/10000 [13:57<00:32, 11.84it/s]
#  96%|█████████▌| 9622/10000 [13:58<00:31, 11.85it/s]
# Picture 19962 is valid
# Iteration 19963 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19963.jpg exists
# Picture 19963 is valid
# Iteration 19964 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19964.jpg exists
# Picture 19964 is valid
# Iteration 19965 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19965.jpg exists
#  96%|█████████▌| 9624/10000 [13:58<00:31, 11.90it/s]
# Picture 19965 is valid
# Iteration 19966 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19966.jpg exists
# Picture 19966 is valid
# Iteration 19967 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19967.jpg exists
# Picture 19967 is valid
# Iteration 19968 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19968.jpg exists
#  96%|█████████▋| 9626/10000 [13:58<00:31, 11.89it/s]
# Picture 19968 is valid
# Iteration 19969 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19969.jpg exists
# Picture 19969 is valid
# Iteration 19970 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19970.jpg exists
#  96%|█████████▋| 9628/10000 [13:58<00:33, 11.08it/s]
#  96%|█████████▋| 9630/10000 [13:58<00:32, 11.36it/s]
# Picture 19970 is valid
# Iteration 19971 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19971.jpg exists
# Picture 19971 is valid
# Iteration 19972 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19972.jpg exists
# Iteration 19973 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19973.jpg exists
# Picture 19973 is valid
# Iteration 19974 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19974.jpg exists
#  96%|█████████▋| 9632/10000 [13:58<00:31, 11.56it/s]
# Picture 19974 is valid
# Iteration 19975 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19975.jpg exists
# Picture 19975 is valid
# Iteration 19976 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19976.jpg exists
# Picture 19976 is valid
# Iteration 19977 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19977.jpg exists
#  96%|█████████▋| 9634/10000 [13:59<00:31, 11.68it/s]
#  96%|█████████▋| 9636/10000 [13:59<00:30, 11.92it/s]
# Picture 19977 is valid
# Iteration 19978 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19978.jpg exists
# Picture 19978 is valid
# Iteration 19979 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19979.jpg exists
# Picture 19979 is valid
# Iteration 19980 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19980.jpg exists
#  96%|█████████▋| 9638/10000 [13:59<00:30, 11.88it/s]
# Picture 19980 is valid
# Iteration 19981 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19981.jpg exists
# Picture 19981 is valid
# Iteration 19982 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19982.jpg exists
# Picture 19982 is valid
# Iteration 19983 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19983.jpg exists
#  96%|█████████▋| 9640/10000 [13:59<00:30, 11.92it/s]
#  96%|█████████▋| 9642/10000 [13:59<00:29, 11.96it/s]
# Picture 19983 is valid
# Iteration 19984 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19984.jpg exists
# Picture 19984 is valid
# Iteration 19985 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19985.jpg exists
# Picture 19985 is valid
# Iteration 19986 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19986.jpg exists
#  96%|█████████▋| 9644/10000 [13:59<00:29, 11.90it/s]
# Picture 19986 is valid
# Iteration 19987 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19987.jpg exists
# Picture 19987 is valid
# Iteration 19988 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19988.jpg exists
# Picture 19988 is valid
# Iteration 19989 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19989.jpg exists
#  96%|█████████▋| 9646/10000 [14:00<00:29, 12.05it/s]
#  96%|█████████▋| 9648/10000 [14:00<00:28, 12.24it/s]
# Picture 19989 is valid
# Iteration 19990 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19990.jpg exists
# Picture 19990 is valid
# Iteration 19991 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19991.jpg exists
# Picture 19991 is valid
# Iteration 19992 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19992.jpg exists
#  96%|█████████▋| 9650/10000 [14:00<00:28, 12.08it/s]
# Picture 19992 is valid
# Iteration 19993 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19993.jpg exists
# Picture 19993 is valid
# Iteration 19994 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19994.jpg exists
#  97%|█████████▋| 9652/10000 [14:00<00:31, 11.07it/s]
# Picture 19994 is valid
# Iteration 19995 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19995.jpg exists
# Picture 19995 is valid
# Iteration 19996 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19996.jpg exists
# Picture 19996 is valid
# Iteration 19997 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19997.jpg exists
#  97%|█████████▋| 9654/10000 [14:00<00:30, 11.30it/s]
#  97%|█████████▋| 9656/10000 [14:00<00:29, 11.61it/s]
# Picture 19997 is valid
# Iteration 19998 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19998.jpg exists
# Picture 19998 is valid
# Iteration 19999 complete
# Image /content/drive/My Drive/CelebAMaskHQ/images/19999.jpg exists
# Picture 19999 is valid
# Iteration 20000 complete
#  97%|█████████▋| 9656/10000 [14:18<00:29, 11.61it/s]
# The number of valid images(images entered) : 9656
